# %%
# %matplotlib notebook
from astropy.table import Table, vstack, join
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import itertools
sys.path.append(f'{os.environ["HOME"]}/Projects/planckClusters/catalogs')
from load_catalogs import load_PSZcatalog
from astropy.io.fits import getheader
from utilities import redshifts_from_papers, get_immediate_subfiles

import warnings
from astropy.utils.exceptions import AstropyWarning
warnings.simplefilter('ignore', category=AstropyWarning)
# Out:
# /home/boada/Projects/swiftXRT/paper/utilities.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def load_MCMCfits(outpath, fields):
    for field in fields:
        if os.path.exists(f'{outpath}/{field}/{field}_mcmcfits.txt'):
            try:
                fit_part = Table.read(f'{outpath}/{field}/{field}_mcmcfits.txt', format='ascii', header_start=0)
            except :
                print(field)
                raise (FileNotFoundError)
            src_part = Table.read(f'{outpath}/{field}/{field}_vtp.detect', format='fits')
            
            fit_part.rename_column('ID', 'INDEX')
            try:
                data_part = join(fit_part, src_part, keys='INDEX', join_type='inner')
            except ValueError:
                continue
        else:
            continue

        # handle the first pass when we only have one part
        try:
            data = vstack([data, data_part])
        except NameError:
            data = data_part
        
    return data

def load_regions(outpath, field, index=0):
    # get all the files
    files = get_immediate_subfiles(f'{outpath}/{field}/spec_files/')
    
    # only want region files -- specific index
    files = [f for f in files if 'bkg.reg' in f]
    
    if len(files) == 0:
        return -1.0
    
    # read the region file and return radius IN PIXELS
    with open(files[0], 'r') as f:
        lines = f.readlines()

    if 'ellipse' in lines[index + 1]:
        r1 = lines[index + 1].split(',')[-3]
        r2 = lines[index + 1].split(',')[-2]
        
        return (float(r1) + float(r2)) / 2
    
    # when making background regions we mask 1.5 * extraction radius for each source
    # here we will take that factor out, because we don't use it in the actual source 
    # extraction
    
    if index:
        return float(lines[index + 1].split(',')[-1][:-2]) / 1.5 

    return float(lines[index + 1].split(',')[-1][:-2])

# %%
datapath = '../data'
data = load_PSZcatalog()
data = data.sort_values('NAME')

fields = [n.replace(' ', '_') for n in data['NAME']]

# read in the MCMC fits
fits = load_MCMCfits(datapath, fields)
# read in the catalog
cat = Table.read('./catalogs/results_table_inspected_0.5_2.0.fits')
# only use non-duplicates
# cat = cat[~cat['DUPLICATE']]

fits.remove_column('R')
df_fits = fits.to_pandas()
df_fits.Field = df_fits.Field.str.replace('_', ' ')
df_cat = cat.to_pandas()
df_cat = df_cat.applymap(lambda x: x.decode() if isinstance(x, bytes) else x)

df_merged = df_cat.merge(df_fits,                                                      
               how='outer',                                              
               left_on=['NAME', 'INDEX'],                                          
               right_on=['Field', 'INDEX'],                                           
               suffixes=('_cat', '_fit'))

# %%
# add a column for the extraction radius and bkg radius
df_merged['EXT_RAD'] = 0.0
df_merged['BKG_RAD'] = 0.0
pixscale = 2.36

for i, row in df_merged.iterrows():
    field = row.Field.replace(' ', '_')
    ext_rad = load_regions(datapath, field, row.INDEX) * pixscale / 60
    bkg_rad = load_regions(datapath, field, 0) * pixscale / 60
    df_merged.at[i, 'EXT_RAD'] = ext_rad
    df_merged.at[i, 'BKG_RAD'] = bkg_rad

df = df_merged[['Field', 'INDEX', 'bg_50', 'EXT_RAD', 'BKG_RAD']]

table = Table.from_pandas(df)

# table.filled(-1.0).write('./catalogs/bkgs_radii.fits', overwrite=True)

# %%
df.plot.scatter('bg_50', 'EXT_RAD')
plt.ylim(1,1000)
plt.loglog()
# Out:
# <img src="data:," width="0">
# []

# %%
df_merged['FLAGS'] = ''
df_merged.loc[df.EXT_RAD > df.BKG_RAD, 'FLAGS'] = 'A'

# %%
df_merged[df_merged.FLAGS != '']
# Out:
#                    NAME     RA_detc   DEC_detc  REDSHIFT  INDEX  PSZ_dist_cat  \
# 51   PSZ2 G011.36+49.42  230.465241   7.705560  0.044200      1      2.030819
# 110  PSZ2 G084.19-47.48  347.601878   7.579836  0.042400      1      4.152838
# 117  PSZ2 G085.82+35.44  258.842066  57.416603  0.027600      1      2.702335
# 157  PSZ2 G114.83+57.25  201.458915  59.328087  0.169517      1      0.428689
# 159  PSZ2 G115.25-72.07   10.462759  -9.306315  0.055500      1      2.466641
# 184  PSZ2 G136.64-25.03   28.198441  36.156433  0.016300      1      5.234638
# 196  PSZ2 G146.35-15.59   43.629608  41.582127  0.017200      1      2.115895
# 222  PSZ2 G173.76+22.92  109.371383  44.084699 -1.000000      5      1.627197
# 223  PSZ2 G173.76+22.92  109.361427  44.138906 -1.000000      6      4.882896
# 255  PSZ2 G210.22+15.56  115.669774   9.373928  0.062000      1      2.367259
# 443  PSZ2 G324.54-44.97  334.494829 -65.180910  0.095100      1      0.343626
# 450  PSZ2 G335.58-46.44  328.523536 -57.865484  0.076000      1      0.215305
#
#      EXPTIME_cat        SN  redCHI2    DOF  ...      Y_ERR          RA  \
# 51   8903.960938  112.9739   1.8980  432.0  ...  46.526254  230.465241
# 110  4303.338379   44.9956   1.6950  179.0  ...  14.503777  347.601878
# 117  3591.577881   -1.0000   2.0379  193.0  ...  22.960577  258.842066
# 157  4933.425781   35.4449   1.7805  120.0  ...  16.638160  201.458915
# 159  6059.879395   -1.0000   1.5526  518.0  ...  54.912269   10.462759
# 184  8186.443359   -1.0000   2.7020  397.0  ...  49.484784   28.198441
# 196   841.591980   -1.0000   1.0103  197.0  ...  16.787040   43.629608
# 222  7824.385742   -1.0000  -1.0000   -1.0  ...  18.780161  109.371383
# 223  7304.895996   -1.0000  -1.0000   -1.0  ...   8.007824  109.361427
# 255  2832.924805   -1.0000   1.9746   99.0  ...  11.691221  115.669774
# 443  3748.110352   42.5519   1.9840  166.0  ...  20.634913  334.494829
# 450  1013.683411   24.8753   1.2770   71.0  ...   8.653110  328.523536
#
#            DEC    RA_ERR   DEC_ERR  PSZ_dist_fit  Extended     EXT_RAD  \
# 51    7.705560  0.037592  0.030501      2.030819         1    9.570560
# 110   7.579836  0.006798  0.009508      4.152838         1   45.397642
# 117  57.416603  0.009640  0.015052      2.702335         1   27.727037
# 157  59.328087  0.010994  0.010907      0.428689         1   12.174244
# 159  -9.306315  0.032901  0.035998      2.466641         1  123.047804
# 184  36.156433  0.029750  0.032440      5.234638         1  220.031453
# 196  41.582127  0.014761  0.011005      2.115895         1   23.365154
# 222  44.084699  0.006668  0.012311      1.627197         1   28.346196
# 223  44.138906  0.004353  0.005250      4.882896         1   21.694746
# 255   9.373928  0.006759  0.007664      2.367259         1   15.462536
# 443 -65.180910  0.013451  0.013527      0.343626         1   11.559175
# 450 -57.865484  0.006857  0.005673      0.215305         1   11.312896
#
#      BKG_RAD  FLAGS
# 51       9.5      A
# 110     11.0      A
# 117     11.0      A
# 157      9.5      A
# 159     11.0      A
# 184     11.0      A
# 196     11.0      A
# 222      9.5      A
# 223      9.5      A
# 255     11.0      A
# 443     11.0      A
# 450     11.0      A
#
# [12 rows x 77 columns]

# %% [markdown]
# The next part is a little harder. We need to know if there are any sources where the extraction radius of one overlaps with the with extraction radius of another. But we only need to do it in single fields. I think what we should do is load the detection catalogs for each field. Then we check.

# %%
current = ''
for i, row in df_merged.iterrows():
    df_tmp = df_merged.loc[df_merged.Field == row.Field]

    if len(df_tmp) >=2 and row.Field != current:
        current = row.Field
        for x, y in itertools.combinations(df_tmp.index, 2):
            x1 = df_merged.iloc[x].X
            y1 = df_merged.iloc[x].Y
            x2 = df_merged.iloc[y].X
            y2 = df_merged.iloc[y].Y
            r1 = abs(df_merged.iloc[x].EXT_RAD) * 60 / 2.36
            r2 = abs(df_merged.iloc[y].EXT_RAD) * 60 / 2.36
            
            # check to see if one extraction circle wholly inside another
            if (r1 - r2)**2 >= ( (x2-x1)**2 + (y2-y1)**2):
                print(f"{df_merged.iloc[x].Field} {df_merged.iloc[x].INDEX} and {df_merged.iloc[y].INDEX} overlap")
                if not 'B' in df_merged.iloc[x].FLAGS:
                    df_merged.at[x, 'FLAGS'] += 'B'
                if not 'B' in df_merged.iloc[y].FLAGS:
                    df_merged.at[y, 'FLAGS'] += 'B'
            # check if the two extraction circles intersect.
            elif (r1 - r2)**2 <= (x1 - x2)**2 + (y1 - y2)**2 <= (r1 + r2)**2:
                print(f"{df_merged.iloc[x].Field} {df_merged.iloc[x].INDEX} and {df_merged.iloc[y].INDEX} intersect")
                if not 'B' in df_merged.iloc[x].FLAGS:
                    df_merged.at[x, 'FLAGS'] += 'B'
                if not 'B' in df_merged.iloc[y].FLAGS:
                    df_merged.at[y, 'FLAGS'] += 'B'
            else:
                print(f"{df_merged.iloc[x].Field} {df_merged.iloc[x].INDEX} and {df_merged.iloc[y].INDEX} do not intersect")
# Out:
# PSZ1 G031.41+28.75 22 and 26 do not intersect
# PSZ1 G031.41+28.75 22 and 33 do not intersect
# PSZ1 G031.41+28.75 22 and 21 do not intersect
# PSZ1 G031.41+28.75 22 and 30 do not intersect
# PSZ1 G031.41+28.75 22 and 31 do not intersect
# PSZ1 G031.41+28.75 22 and 34 do not intersect
# PSZ1 G031.41+28.75 26 and 33 do not intersect
# PSZ1 G031.41+28.75 26 and 21 do not intersect
# PSZ1 G031.41+28.75 26 and 30 do not intersect
# PSZ1 G031.41+28.75 26 and 31 do not intersect
# PSZ1 G031.41+28.75 26 and 34 do not intersect
# PSZ1 G031.41+28.75 33 and 21 do not intersect
# PSZ1 G031.41+28.75 33 and 30 do not intersect
# PSZ1 G031.41+28.75 33 and 31 do not intersect
# PSZ1 G031.41+28.75 33 and 34 do not intersect
# PSZ1 G031.41+28.75 21 and 30 do not intersect
# PSZ1 G031.41+28.75 21 and 31 do not intersect
# PSZ1 G031.41+28.75 21 and 34 do not intersect
# PSZ1 G031.41+28.75 30 and 31 do not intersect
# PSZ1 G031.41+28.75 30 and 34 do not intersect
# PSZ1 G031.41+28.75 31 and 34 do not intersect
# PSZ1 G083.35+76.41 1 and 2 intersect
# PSZ1 G083.35+76.41 1 and 3 do not intersect
# PSZ1 G083.35+76.41 2 and 3 do not intersect
# PSZ1 G221.64-58.20 1 and 2 do not intersect
# PSZ1 G234.85-50.00 14 and 13 do not intersect
# PSZ1 G234.85-50.00 14 and 16 do not intersect
# PSZ1 G234.85-50.00 14 and 20 do not intersect
# PSZ1 G234.85-50.00 13 and 16 do not intersect
# PSZ1 G234.85-50.00 13 and 20 do not intersect
# PSZ1 G234.85-50.00 16 and 20 do not intersect
# PSZ1 G292.00-43.64 7 and 9 do not intersect
# PSZ1 G292.00-43.64 7 and 11 intersect
# PSZ1 G292.00-43.64 7 and 12 do not intersect
# PSZ1 G292.00-43.64 7 and 14 intersect
# PSZ1 G292.00-43.64 7 and 15 intersect
# PSZ1 G292.00-43.64 7 and 16 do not intersect
# PSZ1 G292.00-43.64 7 and 23 do not intersect
# PSZ1 G292.00-43.64 7 and 26 do not intersect
# PSZ1 G292.00-43.64 7 and 29 do not intersect
# PSZ1 G292.00-43.64 7 and 2 do not intersect
# PSZ1 G292.00-43.64 7 and 3 do not intersect
# PSZ1 G292.00-43.64 7 and 6 do not intersect
# PSZ1 G292.00-43.64 7 and 8 do not intersect
# PSZ1 G292.00-43.64 7 and 21 do not intersect
# PSZ1 G292.00-43.64 9 and 11 do not intersect
# PSZ1 G292.00-43.64 9 and 12 do not intersect
# PSZ1 G292.00-43.64 9 and 14 do not intersect
# PSZ1 G292.00-43.64 9 and 15 do not intersect
# PSZ1 G292.00-43.64 9 and 16 do not intersect
# PSZ1 G292.00-43.64 9 and 23 do not intersect
# PSZ1 G292.00-43.64 9 and 26 do not intersect
# PSZ1 G292.00-43.64 9 and 29 do not intersect
# PSZ1 G292.00-43.64 9 and 2 do not intersect
# PSZ1 G292.00-43.64 9 and 3 do not intersect
# PSZ1 G292.00-43.64 9 and 6 do not intersect
# PSZ1 G292.00-43.64 9 and 8 do not intersect
# PSZ1 G292.00-43.64 9 and 21 do not intersect
# PSZ1 G292.00-43.64 11 and 12 do not intersect
# PSZ1 G292.00-43.64 11 and 14 intersect
# PSZ1 G292.00-43.64 11 and 15 intersect
# PSZ1 G292.00-43.64 11 and 16 intersect
# PSZ1 G292.00-43.64 11 and 23 do not intersect
# PSZ1 G292.00-43.64 11 and 26 do not intersect
# PSZ1 G292.00-43.64 11 and 29 do not intersect
# PSZ1 G292.00-43.64 11 and 2 do not intersect
# PSZ1 G292.00-43.64 11 and 3 do not intersect
# PSZ1 G292.00-43.64 11 and 6 do not intersect
# PSZ1 G292.00-43.64 11 and 8 do not intersect
# PSZ1 G292.00-43.64 11 and 21 do not intersect
# PSZ1 G292.00-43.64 12 and 14 do not intersect
# PSZ1 G292.00-43.64 12 and 15 do not intersect
# PSZ1 G292.00-43.64 12 and 16 do not intersect
# PSZ1 G292.00-43.64 12 and 23 do not intersect
# PSZ1 G292.00-43.64 12 and 26 do not intersect
# PSZ1 G292.00-43.64 12 and 29 do not intersect
# PSZ1 G292.00-43.64 12 and 2 do not intersect
# PSZ1 G292.00-43.64 12 and 3 do not intersect
# PSZ1 G292.00-43.64 12 and 6 do not intersect
# PSZ1 G292.00-43.64 12 and 8 do not intersect
# PSZ1 G292.00-43.64 12 and 21 do not intersect
# PSZ1 G292.00-43.64 14 and 15 intersect
# PSZ1 G292.00-43.64 14 and 16 intersect
# PSZ1 G292.00-43.64 14 and 23 do not intersect
# PSZ1 G292.00-43.64 14 and 26 do not intersect
# PSZ1 G292.00-43.64 14 and 29 do not intersect
# PSZ1 G292.00-43.64 14 and 2 do not intersect
# PSZ1 G292.00-43.64 14 and 3 do not intersect
# PSZ1 G292.00-43.64 14 and 6 do not intersect
# PSZ1 G292.00-43.64 14 and 8 do not intersect
# PSZ1 G292.00-43.64 14 and 21 intersect
# PSZ1 G292.00-43.64 15 and 16 intersect
# PSZ1 G292.00-43.64 15 and 23 do not intersect
# PSZ1 G292.00-43.64 15 and 26 do not intersect
# PSZ1 G292.00-43.64 15 and 29 do not intersect
# PSZ1 G292.00-43.64 15 and 2 do not intersect
# PSZ1 G292.00-43.64 15 and 3 do not intersect
# PSZ1 G292.00-43.64 15 and 6 do not intersect
# PSZ1 G292.00-43.64 15 and 8 do not intersect
# PSZ1 G292.00-43.64 15 and 21 do not intersect
# PSZ1 G292.00-43.64 16 and 23 do not intersect
# PSZ1 G292.00-43.64 16 and 26 do not intersect
# PSZ1 G292.00-43.64 16 and 29 do not intersect
# PSZ1 G292.00-43.64 16 and 2 do not intersect
# PSZ1 G292.00-43.64 16 and 3 do not intersect
# PSZ1 G292.00-43.64 16 and 6 do not intersect
# PSZ1 G292.00-43.64 16 and 8 do not intersect
# PSZ1 G292.00-43.64 16 and 21 do not intersect
# PSZ1 G292.00-43.64 23 and 26 do not intersect
# PSZ1 G292.00-43.64 23 and 29 do not intersect
# PSZ1 G292.00-43.64 23 and 2 do not intersect
# PSZ1 G292.00-43.64 23 and 3 do not intersect
# PSZ1 G292.00-43.64 23 and 6 do not intersect
# PSZ1 G292.00-43.64 23 and 8 do not intersect
# PSZ1 G292.00-43.64 23 and 21 do not intersect
# PSZ1 G292.00-43.64 26 and 29 do not intersect
# PSZ1 G292.00-43.64 26 and 2 do not intersect
# PSZ1 G292.00-43.64 26 and 3 do not intersect
# PSZ1 G292.00-43.64 26 and 6 do not intersect
# PSZ1 G292.00-43.64 26 and 8 do not intersect
# PSZ1 G292.00-43.64 26 and 21 do not intersect
# PSZ1 G292.00-43.64 29 and 2 do not intersect
# PSZ1 G292.00-43.64 29 and 3 do not intersect
# PSZ1 G292.00-43.64 29 and 6 do not intersect
# PSZ1 G292.00-43.64 29 and 8 do not intersect
# PSZ1 G292.00-43.64 29 and 21 do not intersect
# PSZ1 G292.00-43.64 2 and 3 do not intersect
# PSZ1 G292.00-43.64 2 and 6 do not intersect
# PSZ1 G292.00-43.64 2 and 8 do not intersect
# PSZ1 G292.00-43.64 2 and 21 do not intersect
# PSZ1 G292.00-43.64 3 and 6 do not intersect
# PSZ1 G292.00-43.64 3 and 8 do not intersect
# PSZ1 G292.00-43.64 3 and 21 do not intersect
# PSZ1 G292.00-43.64 6 and 8 do not intersect
# PSZ1 G292.00-43.64 6 and 21 do not intersect
# PSZ1 G292.00-43.64 8 and 21 do not intersect
# PSZ2 G028.08+10.79 2 and 1 do not intersect
# PSZ2 G039.34+73.28 16 and 19 do not intersect
# PSZ2 G039.34+73.28 16 and 21 do not intersect
# PSZ2 G039.34+73.28 16 and 22 do not intersect
# PSZ2 G039.34+73.28 19 and 21 do not intersect
# PSZ2 G039.34+73.28 19 and 22 do not intersect
# PSZ2 G039.34+73.28 21 and 22 do not intersect
# PSZ2 G045.20+15.63 2 and 1 overlap
# PSZ2 G051.40-61.15 3 and 2 do not intersect
# PSZ2 G052.35-31.98 1 and 2 intersect
# PSZ2 G056.79-11.60 1 and 2 intersect
# PSZ2 G078.36-47.22 1 and 2 overlap
# PSZ2 G078.36-47.22 1 and 3 do not intersect
# PSZ2 G078.36-47.22 2 and 3 overlap
# PSZ2 G084.69+42.28 4 and 3 overlap
# PSZ2 G094.00+27.41 3 and 4 intersect
# PSZ2 G094.31-11.31 1 and 2 do not intersect
# PSZ2 G094.44+36.13 5 and 8 do not intersect
# PSZ2 G094.44+36.13 5 and 3 do not intersect
# PSZ2 G094.44+36.13 5 and 6 do not intersect
# PSZ2 G094.44+36.13 8 and 3 do not intersect
# PSZ2 G094.44+36.13 8 and 6 intersect
# PSZ2 G094.44+36.13 3 and 6 do not intersect
# PSZ2 G105.76+54.73 1 and 2 do not intersect
# PSZ2 G114.14+58.96 2 and 1 intersect
# PSZ2 G125.68-64.12 1 and 2 intersect
# PSZ2 G132.47-17.27 2 and 1 intersect
# PSZ2 G137.74-27.08 1 and 2 overlap
# PSZ2 G143.44+53.66 1 and 2 do not intersect
# PSZ2 G147.88+53.24 1 and 2 do not intersect
# PSZ2 G150.64-14.21 5 and 3 do not intersect
# PSZ2 G151.90+11.63 2 and 1 do not intersect
# PSZ2 G154.13+40.19 2 and 1 do not intersect
# PSZ2 G162.49-71.98 1 and 2 intersect
# PSZ2 G170.26+73.90 1 and 3 do not intersect
# PSZ2 G170.26+73.90 1 and 2 do not intersect
# PSZ2 G170.26+73.90 3 and 2 do not intersect
# PSZ2 G172.63+35.15 3 and 2 overlap
# PSZ2 G173.76+22.92 5 and 6 overlap
# PSZ2 G199.61+53.41 1 and 2 do not intersect
# PSZ2 G202.61-26.26 10 and 11 do not intersect
# PSZ2 G202.61-26.26 10 and 8 do not intersect
# PSZ2 G202.61-26.26 10 and 12 do not intersect
# PSZ2 G202.61-26.26 11 and 8 do not intersect
# PSZ2 G202.61-26.26 11 and 12 intersect
# PSZ2 G202.61-26.26 8 and 12 do not intersect
# PSZ2 G206.45+13.89 1 and 2 intersect
# PSZ2 G225.56-27.27 3 and 2 intersect
# PSZ2 G225.84+41.84 2 and 1 intersect
# PSZ2 G226.12-19.51 2 and 1 do not intersect
# PSZ2 G226.75+48.95 1 and 4 do not intersect
# PSZ2 G226.75+48.95 1 and 5 do not intersect
# PSZ2 G226.75+48.95 1 and 3 do not intersect
# PSZ2 G226.75+48.95 1 and 6 do not intersect
# PSZ2 G226.75+48.95 4 and 5 intersect
# PSZ2 G226.75+48.95 4 and 3 intersect
# PSZ2 G226.75+48.95 4 and 6 intersect
# PSZ2 G226.75+48.95 5 and 3 intersect
# PSZ2 G226.75+48.95 5 and 6 intersect
# PSZ2 G226.75+48.95 3 and 6 do not intersect
# PSZ2 G230.29-47.13 1 and 2 do not intersect
# PSZ2 G234.52+82.85 1 and 2 do not intersect
# PSZ2 G260.80+06.71 2 and 1 do not intersect
# PSZ2 G268.34-43.64 11 and 16 do not intersect
# PSZ2 G268.34-43.64 11 and 17 do not intersect
# PSZ2 G268.34-43.64 11 and 21 do not intersect
# PSZ2 G268.34-43.64 11 and 6 do not intersect
# PSZ2 G268.34-43.64 11 and 8 do not intersect
# PSZ2 G268.34-43.64 11 and 18 do not intersect
# PSZ2 G268.34-43.64 11 and 19 do not intersect
# PSZ2 G268.34-43.64 16 and 17 do not intersect
# PSZ2 G268.34-43.64 16 and 21 do not intersect
# PSZ2 G268.34-43.64 16 and 6 do not intersect
# PSZ2 G268.34-43.64 16 and 8 do not intersect
# PSZ2 G268.34-43.64 16 and 18 do not intersect
# PSZ2 G268.34-43.64 16 and 19 do not intersect
# PSZ2 G268.34-43.64 17 and 21 do not intersect
# PSZ2 G268.34-43.64 17 and 6 do not intersect
# PSZ2 G268.34-43.64 17 and 8 do not intersect
# PSZ2 G268.34-43.64 17 and 18 do not intersect
# PSZ2 G268.34-43.64 17 and 19 do not intersect
# PSZ2 G268.34-43.64 21 and 6 do not intersect
# PSZ2 G268.34-43.64 21 and 8 do not intersect
# PSZ2 G268.34-43.64 21 and 18 do not intersect
# PSZ2 G268.34-43.64 21 and 19 do not intersect
# PSZ2 G268.34-43.64 6 and 8 do not intersect
# PSZ2 G268.34-43.64 6 and 18 do not intersect
# PSZ2 G268.34-43.64 6 and 19 do not intersect
# PSZ2 G268.34-43.64 8 and 18 do not intersect
# PSZ2 G268.34-43.64 8 and 19 do not intersect
# PSZ2 G268.34-43.64 18 and 19 do not intersect
# PSZ2 G270.93-58.78 3 and 2 intersect
# PSZ2 G271.28-36.11 5 and 9 do not intersect
# PSZ2 G271.28-36.11 5 and 2 do not intersect
# PSZ2 G271.28-36.11 5 and 3 intersect
# PSZ2 G271.28-36.11 5 and 6 do not intersect
# PSZ2 G271.28-36.11 5 and 8 do not intersect
# PSZ2 G271.28-36.11 9 and 2 do not intersect
# PSZ2 G271.28-36.11 9 and 3 do not intersect
# PSZ2 G271.28-36.11 9 and 6 do not intersect
# PSZ2 G271.28-36.11 9 and 8 do not intersect
# PSZ2 G271.28-36.11 2 and 3 do not intersect
# PSZ2 G271.28-36.11 2 and 6 do not intersect
# PSZ2 G271.28-36.11 2 and 8 do not intersect
# PSZ2 G271.28-36.11 3 and 6 do not intersect
# PSZ2 G271.28-36.11 3 and 8 do not intersect
# PSZ2 G271.28-36.11 6 and 8 do not intersect
# PSZ2 G276.09-41.53 2 and 3 do not intersect
# PSZ2 G281.09-42.51 3 and 2 do not intersect
# PSZ2 G282.14+38.29 2 and 1 do not intersect
# PSZ2 G283.91+73.87 2 and 3 do not intersect
# PSZ2 G283.91+73.87 2 and 4 do not intersect
# PSZ2 G283.91+73.87 3 and 4 do not intersect
# PSZ2 G287.54+58.63 3 and 2 do not intersect
# PSZ2 G288.87-32.97 2 and 1 intersect
# PSZ2 G296.91-07.00 1 and 2 intersect
# PSZ2 G303.03-68.49 2 and 3 do not intersect
# PSZ2 G308.04-15.48 1 and 2 do not intersect
# PSZ2 G333.59+73.19 2 and 1 do not intersect
# PSZ2 G339.63-69.34 4 and 2 do not intersect
# PSZ2 G345.32-59.97 4 and 1 do not intersect
# PSZ2 G345.32-59.97 4 and 2 intersect
# PSZ2 G345.32-59.97 4 and 5 intersect
# PSZ2 G345.32-59.97 1 and 2 do not intersect
# PSZ2 G345.32-59.97 1 and 5 do not intersect
# PSZ2 G345.32-59.97 2 and 5 do not intersect
# PSZ2 G347.27-52.46 2 and 3 intersect
# PSZ2 G347.58-35.35 3 and 1 intersect
# PSZ2 G347.58-35.35 3 and 2 intersect
# PSZ2 G347.58-35.35 1 and 2 intersect
# PSZ2 G358.34-47.31 3 and 4 do not intersect
# PSZ2 G359.07-32.12 1 and 4 do not intersect
# PSZ2 G359.07-32.12 1 and 2 do not intersect
# PSZ2 G359.07-32.12 4 and 2 do not intersect
# PSZ1 G031.41+28.75 22 and 26 do not intersect
# PSZ1 G031.41+28.75 22 and 33 do not intersect
# PSZ1 G031.41+28.75 22 and 21 do not intersect
# PSZ1 G031.41+28.75 22 and 30 do not intersect
# PSZ1 G031.41+28.75 22 and 31 do not intersect
# PSZ1 G031.41+28.75 22 and 34 do not intersect
# PSZ1 G031.41+28.75 26 and 33 do not intersect
# PSZ1 G031.41+28.75 26 and 21 do not intersect
# PSZ1 G031.41+28.75 26 and 30 do not intersect
# PSZ1 G031.41+28.75 26 and 31 do not intersect
# PSZ1 G031.41+28.75 26 and 34 do not intersect
# PSZ1 G031.41+28.75 33 and 21 do not intersect
# PSZ1 G031.41+28.75 33 and 30 do not intersect
# PSZ1 G031.41+28.75 33 and 31 do not intersect
# PSZ1 G031.41+28.75 33 and 34 do not intersect
# PSZ1 G031.41+28.75 21 and 30 do not intersect
# PSZ1 G031.41+28.75 21 and 31 do not intersect
# PSZ1 G031.41+28.75 21 and 34 do not intersect
# PSZ1 G031.41+28.75 30 and 31 do not intersect
# PSZ1 G031.41+28.75 30 and 34 do not intersect
# PSZ1 G031.41+28.75 31 and 34 do not intersect
# PSZ1 G083.35+76.41 1 and 2 intersect
# PSZ1 G083.35+76.41 1 and 3 do not intersect
# PSZ1 G083.35+76.41 2 and 3 do not intersect
# PSZ1 G221.64-58.20 1 and 2 do not intersect
# PSZ1 G234.85-50.00 14 and 13 do not intersect
# PSZ1 G234.85-50.00 14 and 16 do not intersect
# PSZ1 G234.85-50.00 14 and 20 do not intersect
# PSZ1 G234.85-50.00 13 and 16 do not intersect
# PSZ1 G234.85-50.00 13 and 20 do not intersect
# PSZ1 G234.85-50.00 16 and 20 do not intersect
# PSZ1 G292.00-43.64 7 and 9 do not intersect
# PSZ1 G292.00-43.64 7 and 11 intersect
# PSZ1 G292.00-43.64 7 and 12 do not intersect
# PSZ1 G292.00-43.64 7 and 14 intersect
# PSZ1 G292.00-43.64 7 and 15 intersect
# PSZ1 G292.00-43.64 7 and 16 do not intersect
# PSZ1 G292.00-43.64 7 and 23 do not intersect
# PSZ1 G292.00-43.64 7 and 26 do not intersect
# PSZ1 G292.00-43.64 7 and 29 do not intersect
# PSZ1 G292.00-43.64 7 and 2 do not intersect
# PSZ1 G292.00-43.64 7 and 3 do not intersect
# PSZ1 G292.00-43.64 7 and 6 do not intersect
# PSZ1 G292.00-43.64 7 and 8 do not intersect
# PSZ1 G292.00-43.64 7 and 21 do not intersect
# PSZ1 G292.00-43.64 9 and 11 do not intersect
# PSZ1 G292.00-43.64 9 and 12 do not intersect
# PSZ1 G292.00-43.64 9 and 14 do not intersect
# PSZ1 G292.00-43.64 9 and 15 do not intersect
# PSZ1 G292.00-43.64 9 and 16 do not intersect
# PSZ1 G292.00-43.64 9 and 23 do not intersect
# PSZ1 G292.00-43.64 9 and 26 do not intersect
# PSZ1 G292.00-43.64 9 and 29 do not intersect
# PSZ1 G292.00-43.64 9 and 2 do not intersect
# PSZ1 G292.00-43.64 9 and 3 do not intersect
# PSZ1 G292.00-43.64 9 and 6 do not intersect
# PSZ1 G292.00-43.64 9 and 8 do not intersect
# PSZ1 G292.00-43.64 9 and 21 do not intersect
# PSZ1 G292.00-43.64 11 and 12 do not intersect
# PSZ1 G292.00-43.64 11 and 14 intersect
# PSZ1 G292.00-43.64 11 and 15 intersect
# PSZ1 G292.00-43.64 11 and 16 intersect
# PSZ1 G292.00-43.64 11 and 23 do not intersect
# PSZ1 G292.00-43.64 11 and 26 do not intersect
# PSZ1 G292.00-43.64 11 and 29 do not intersect
# PSZ1 G292.00-43.64 11 and 2 do not intersect
# PSZ1 G292.00-43.64 11 and 3 do not intersect
# PSZ1 G292.00-43.64 11 and 6 do not intersect
# PSZ1 G292.00-43.64 11 and 8 do not intersect
# PSZ1 G292.00-43.64 11 and 21 do not intersect
# PSZ1 G292.00-43.64 12 and 14 do not intersect
# PSZ1 G292.00-43.64 12 and 15 do not intersect
# PSZ1 G292.00-43.64 12 and 16 do not intersect
# PSZ1 G292.00-43.64 12 and 23 do not intersect
# PSZ1 G292.00-43.64 12 and 26 do not intersect
# PSZ1 G292.00-43.64 12 and 29 do not intersect
# PSZ1 G292.00-43.64 12 and 2 do not intersect
# PSZ1 G292.00-43.64 12 and 3 do not intersect
# PSZ1 G292.00-43.64 12 and 6 do not intersect
# PSZ1 G292.00-43.64 12 and 8 do not intersect
# PSZ1 G292.00-43.64 12 and 21 do not intersect
# PSZ1 G292.00-43.64 14 and 15 intersect
# PSZ1 G292.00-43.64 14 and 16 intersect
# PSZ1 G292.00-43.64 14 and 23 do not intersect
# PSZ1 G292.00-43.64 14 and 26 do not intersect
# PSZ1 G292.00-43.64 14 and 29 do not intersect
# PSZ1 G292.00-43.64 14 and 2 do not intersect
# PSZ1 G292.00-43.64 14 and 3 do not intersect
# PSZ1 G292.00-43.64 14 and 6 do not intersect
# PSZ1 G292.00-43.64 14 and 8 do not intersect
# PSZ1 G292.00-43.64 14 and 21 intersect
# PSZ1 G292.00-43.64 15 and 16 intersect
# PSZ1 G292.00-43.64 15 and 23 do not intersect
# PSZ1 G292.00-43.64 15 and 26 do not intersect
# PSZ1 G292.00-43.64 15 and 29 do not intersect
# PSZ1 G292.00-43.64 15 and 2 do not intersect
# PSZ1 G292.00-43.64 15 and 3 do not intersect
# PSZ1 G292.00-43.64 15 and 6 do not intersect
# PSZ1 G292.00-43.64 15 and 8 do not intersect
# PSZ1 G292.00-43.64 15 and 21 do not intersect
# PSZ1 G292.00-43.64 16 and 23 do not intersect
# PSZ1 G292.00-43.64 16 and 26 do not intersect
# PSZ1 G292.00-43.64 16 and 29 do not intersect
# PSZ1 G292.00-43.64 16 and 2 do not intersect
# PSZ1 G292.00-43.64 16 and 3 do not intersect
# PSZ1 G292.00-43.64 16 and 6 do not intersect
# PSZ1 G292.00-43.64 16 and 8 do not intersect
# PSZ1 G292.00-43.64 16 and 21 do not intersect
# PSZ1 G292.00-43.64 23 and 26 do not intersect
# PSZ1 G292.00-43.64 23 and 29 do not intersect
# PSZ1 G292.00-43.64 23 and 2 do not intersect
# PSZ1 G292.00-43.64 23 and 3 do not intersect
# PSZ1 G292.00-43.64 23 and 6 do not intersect
# PSZ1 G292.00-43.64 23 and 8 do not intersect
# PSZ1 G292.00-43.64 23 and 21 do not intersect
# PSZ1 G292.00-43.64 26 and 29 do not intersect
# PSZ1 G292.00-43.64 26 and 2 do not intersect
# PSZ1 G292.00-43.64 26 and 3 do not intersect
# PSZ1 G292.00-43.64 26 and 6 do not intersect
# PSZ1 G292.00-43.64 26 and 8 do not intersect
# PSZ1 G292.00-43.64 26 and 21 do not intersect
# PSZ1 G292.00-43.64 29 and 2 do not intersect
# PSZ1 G292.00-43.64 29 and 3 do not intersect
# PSZ1 G292.00-43.64 29 and 6 do not intersect
# PSZ1 G292.00-43.64 29 and 8 do not intersect
# PSZ1 G292.00-43.64 29 and 21 do not intersect
# PSZ1 G292.00-43.64 2 and 3 do not intersect
# PSZ1 G292.00-43.64 2 and 6 do not intersect
# PSZ1 G292.00-43.64 2 and 8 do not intersect
# PSZ1 G292.00-43.64 2 and 21 do not intersect
# PSZ1 G292.00-43.64 3 and 6 do not intersect
# PSZ1 G292.00-43.64 3 and 8 do not intersect
# PSZ1 G292.00-43.64 3 and 21 do not intersect
# PSZ1 G292.00-43.64 6 and 8 do not intersect
# PSZ1 G292.00-43.64 6 and 21 do not intersect
# PSZ1 G292.00-43.64 8 and 21 do not intersect
# PSZ2 G028.08+10.79 2 and 1 do not intersect
# PSZ2 G039.34+73.28 16 and 19 do not intersect
# PSZ2 G039.34+73.28 16 and 21 do not intersect
# PSZ2 G039.34+73.28 16 and 22 do not intersect
# PSZ2 G039.34+73.28 19 and 21 do not intersect
# PSZ2 G039.34+73.28 19 and 22 do not intersect
# PSZ2 G039.34+73.28 21 and 22 do not intersect
# PSZ2 G045.20+15.63 2 and 1 overlap
# PSZ2 G051.40-61.15 3 and 2 do not intersect
# PSZ2 G056.79-11.60 1 and 2 intersect
# PSZ2 G078.36-47.22 1 and 2 overlap
# PSZ2 G078.36-47.22 1 and 3 do not intersect
# PSZ2 G078.36-47.22 2 and 3 overlap
# PSZ2 G084.69+42.28 4 and 3 overlap
# PSZ2 G094.00+27.41 3 and 4 intersect
# PSZ2 G094.31-11.31 1 and 2 do not intersect
# PSZ2 G094.44+36.13 5 and 8 do not intersect
# PSZ2 G094.44+36.13 5 and 3 do not intersect
# PSZ2 G094.44+36.13 5 and 6 do not intersect
# PSZ2 G094.44+36.13 8 and 3 do not intersect
# PSZ2 G094.44+36.13 8 and 6 intersect
# PSZ2 G094.44+36.13 3 and 6 do not intersect
# PSZ2 G096.10+12.46 4 and 7 do not intersect
# PSZ2 G096.10+12.46 4 and 9 do not intersect
# PSZ2 G096.10+12.46 7 and 9 do not intersect
# PSZ2 G114.14+58.96 2 and 1 intersect
# PSZ2 G132.47-17.27 2 and 1 intersect
# PSZ2 G137.74-27.08 1 and 2 overlap
# PSZ2 G143.44+53.66 1 and 2 do not intersect
# PSZ2 G147.88+53.24 1 and 2 do not intersect
# PSZ2 G150.64-14.21 5 and 3 do not intersect
# PSZ2 G151.90+11.63 2 and 1 do not intersect
# PSZ2 G154.13+40.19 2 and 1 do not intersect
# PSZ2 G170.26+73.90 1 and 3 do not intersect
# PSZ2 G170.26+73.90 1 and 2 do not intersect
# PSZ2 G170.26+73.90 3 and 2 do not intersect
# PSZ2 G172.63+35.15 3 and 2 overlap
# PSZ2 G202.61-26.26 10 and 11 do not intersect
# PSZ2 G202.61-26.26 10 and 8 do not intersect
# PSZ2 G202.61-26.26 10 and 12 do not intersect
# PSZ2 G202.61-26.26 11 and 8 do not intersect
# PSZ2 G202.61-26.26 11 and 12 intersect
# PSZ2 G202.61-26.26 8 and 12 do not intersect
# PSZ2 G225.56-27.27 3 and 2 intersect
# PSZ2 G225.84+41.84 2 and 1 intersect
# PSZ2 G226.12-19.51 2 and 1 do not intersect
# PSZ2 G226.75+48.95 1 and 4 do not intersect
# PSZ2 G226.75+48.95 1 and 5 do not intersect
# PSZ2 G226.75+48.95 1 and 3 do not intersect
# PSZ2 G226.75+48.95 1 and 6 do not intersect
# PSZ2 G226.75+48.95 4 and 5 intersect
# PSZ2 G226.75+48.95 4 and 3 intersect
# PSZ2 G226.75+48.95 4 and 6 intersect
# PSZ2 G226.75+48.95 5 and 3 intersect
# PSZ2 G226.75+48.95 5 and 6 intersect
# PSZ2 G226.75+48.95 3 and 6 do not intersect
# PSZ2 G230.29-47.13 1 and 2 do not intersect
# PSZ2 G234.52+82.85 1 and 2 do not intersect
# PSZ2 G260.80+06.71 2 and 1 do not intersect
# PSZ2 G268.34-43.64 11 and 16 do not intersect
# PSZ2 G268.34-43.64 11 and 17 do not intersect
# PSZ2 G268.34-43.64 11 and 21 do not intersect
# PSZ2 G268.34-43.64 11 and 6 do not intersect
# PSZ2 G268.34-43.64 11 and 8 do not intersect
# PSZ2 G268.34-43.64 11 and 18 do not intersect
# PSZ2 G268.34-43.64 11 and 19 do not intersect
# PSZ2 G268.34-43.64 16 and 17 do not intersect
# PSZ2 G268.34-43.64 16 and 21 do not intersect
# PSZ2 G268.34-43.64 16 and 6 do not intersect
# PSZ2 G268.34-43.64 16 and 8 do not intersect
# PSZ2 G268.34-43.64 16 and 18 do not intersect
# PSZ2 G268.34-43.64 16 and 19 do not intersect
# PSZ2 G268.34-43.64 17 and 21 do not intersect
# PSZ2 G268.34-43.64 17 and 6 do not intersect
# PSZ2 G268.34-43.64 17 and 8 do not intersect
# PSZ2 G268.34-43.64 17 and 18 do not intersect
# PSZ2 G268.34-43.64 17 and 19 do not intersect
# PSZ2 G268.34-43.64 21 and 6 do not intersect
# PSZ2 G268.34-43.64 21 and 8 do not intersect
# PSZ2 G268.34-43.64 21 and 18 do not intersect
# PSZ2 G268.34-43.64 21 and 19 do not intersect
# PSZ2 G268.34-43.64 6 and 8 do not intersect
# PSZ2 G268.34-43.64 6 and 18 do not intersect
# PSZ2 G268.34-43.64 6 and 19 do not intersect
# PSZ2 G268.34-43.64 8 and 18 do not intersect
# PSZ2 G268.34-43.64 8 and 19 do not intersect
# PSZ2 G268.34-43.64 18 and 19 do not intersect
# PSZ2 G270.93-58.78 3 and 2 intersect
# PSZ2 G271.28-36.11 5 and 9 do not intersect
# PSZ2 G271.28-36.11 5 and 2 do not intersect
# PSZ2 G271.28-36.11 5 and 3 intersect
# PSZ2 G271.28-36.11 5 and 6 do not intersect
# PSZ2 G271.28-36.11 5 and 8 do not intersect
# PSZ2 G271.28-36.11 9 and 2 do not intersect
# PSZ2 G271.28-36.11 9 and 3 do not intersect
# PSZ2 G271.28-36.11 9 and 6 do not intersect
# PSZ2 G271.28-36.11 9 and 8 do not intersect
# PSZ2 G271.28-36.11 2 and 3 do not intersect
# PSZ2 G271.28-36.11 2 and 6 do not intersect
# PSZ2 G271.28-36.11 2 and 8 do not intersect
# PSZ2 G271.28-36.11 3 and 6 do not intersect
# PSZ2 G271.28-36.11 3 and 8 do not intersect
# PSZ2 G271.28-36.11 6 and 8 do not intersect
# PSZ2 G281.09-42.51 3 and 2 do not intersect
# PSZ2 G282.14+38.29 2 and 1 do not intersect
# PSZ2 G287.54+58.63 3 and 2 do not intersect
# PSZ2 G288.87-32.97 2 and 1 intersect
# PSZ2 G296.91-07.00 1 and 2 intersect
# PSZ2 G303.03-68.49 2 and 3 do not intersect
# PSZ2 G308.04-15.48 1 and 2 do not intersect
# PSZ2 G333.59+73.19 2 and 1 do not intersect
# PSZ2 G339.63-69.34 4 and 2 do not intersect
# PSZ2 G345.32-59.97 4 and 1 do not intersect
# PSZ2 G345.32-59.97 4 and 2 intersect
# PSZ2 G345.32-59.97 4 and 5 intersect
# PSZ2 G345.32-59.97 1 and 2 do not intersect
# PSZ2 G345.32-59.97 1 and 5 do not intersect
# PSZ2 G345.32-59.97 2 and 5 do not intersect
# PSZ2 G347.58-35.35 3 and 1 intersect
# PSZ2 G347.58-35.35 3 and 2 intersect
# PSZ2 G347.58-35.35 1 and 2 intersect
# PSZ2 G359.07-32.12 1 and 4 do not intersect
# PSZ2 G359.07-32.12 1 and 2 do not intersect
# PSZ2 G359.07-32.12 4 and 2 do not intersect

# %%
df_cat = df_cat.merge(df_merged[['Field', 'INDEX', 'FLAGS']],                                                      
               how='left',                                              
               left_on=['NAME', 'INDEX'],                                          
               right_on=['Field', 'INDEX'],                                           
               suffixes=('_cat', '_fit'))

# %%
df_cat[(df_cat.FLAGS != '') & (~df_cat.DUPLICATE)][['Field', 'REDSHIFT', 'INDEX', 'FLAGS', 'DUPLICATE']]
# Out:
#                   Field  REDSHIFT  INDEX FLAGS  DUPLICATE
# 28   PSZ1 G292.00-43.64 -1.000000      7     B      False
# 51   PSZ2 G011.36+49.42  0.044200      1     A      False
# 72   PSZ2 G045.20+15.63 -1.000000      2     B      False
# 80   PSZ2 G052.35-31.98  0.264975      1     B      False
# 81   PSZ2 G052.35-31.98  0.264975      2     B      False
# 84   PSZ2 G056.79-11.60  0.122000      1     B      False
# 103  PSZ2 G078.36-47.22  0.169600      1     B      False
# 104  PSZ2 G078.36-47.22  0.169600      2     B      False
# 110  PSZ2 G084.19-47.48  0.042400      1     A      False
# 114  PSZ2 G084.69+42.28  0.130000      4     B      False
# 117  PSZ2 G085.82+35.44  0.027600      1     A      False
# 128  PSZ2 G094.00+27.41  0.331500      3     B      False
# 131  PSZ2 G094.44+36.13  0.453000      8     B      False
# 153  PSZ2 G114.14+58.96  0.115583      2     B      False
# 157  PSZ2 G114.83+57.25  0.169517      1     A      False
# 159  PSZ2 G115.25-72.07  0.055500      1     A      False
# 179  PSZ2 G132.47-17.27  0.341000      2     B      False
# 184  PSZ2 G136.64-25.03  0.016300      1     A      False
# 186  PSZ2 G137.74-27.08  0.087200      1     B      False
# 196  PSZ2 G146.35-15.59  0.017200      1     A      False
# 210  PSZ2 G162.49-71.98  0.210800      1     B      False
# 211  PSZ2 G162.49-71.98  0.210800      2     B      False
# 221  PSZ2 G172.63+35.15  0.126700      3     B      False
# 222  PSZ2 G173.76+22.92 -1.000000      5    AB      False
# 246  PSZ2 G202.61-26.26 -1.000000     11     B      False
# 251  PSZ2 G206.45+13.89  0.381000      1     B      False
# 255  PSZ2 G210.22+15.56  0.062000      1     A      False
# 272  PSZ2 G225.56-27.27  0.170600      3     B      False
# 274  PSZ2 G225.84+41.84  0.206000      2     B      False
# 279  PSZ2 G226.75+48.95  0.224500      5     B      False
# 349  PSZ2 G270.93-58.78  0.278000      3     B      False
# 354  PSZ2 G271.28-36.11  0.250000      5     B      False
# 399  PSZ2 G288.87-32.97 -1.000000      2     B      False
# 413  PSZ2 G296.91-07.00  0.310000      1     B      False
# 443  PSZ2 G324.54-44.97  0.095100      1     A      False
# 450  PSZ2 G335.58-46.44  0.076000      1     A      False
# 460  PSZ2 G345.32-59.97  0.270000      4     B      False
# 462  PSZ2 G347.27-52.46  0.240000      3     B      False
# 463  PSZ2 G347.58-35.35  0.220000      3     B      False

# %%
table = Table.from_pandas(df_cat)
table.filled(-1.0).write('./catalogs/results_table_inspected_flagged_0.5_2.0.fits', overwrite=True)
